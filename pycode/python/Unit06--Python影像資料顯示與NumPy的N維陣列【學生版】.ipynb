# %% [markdown]
# 【臺北大學】Python程式設計<br>
# 【授課老師】[陳祥輝 (Email : HsiangHui.Chen@gmail.com)](mailto:HsiangHui.Chen@gmail.com)<br>
# 【facebook】[陳祥輝老師的臉書 (歡迎加好友)](https://goo.gl/osivhx)<br>
# 【參考書籍】[從零開始學Python程式設計（適用Python 3.5以上）](http://www.drmaster.com.tw/Bookinfo.asp?BookID=MP31821)<br>
# 【主要議題】Python影像資料顯示與NumPy的ndarray

# %% [markdown]
# ### 【重點提要】
# ###### matplotlib
# * imread() : 讀入影像檔案，成為 ndarray
# * imshow() : 將圖檔(ndarry)置放於X-Y坐標軸上
# * show() : 將圖形顯示出來
#
# ###### NumPy : Base N-dimensional array package
# * ndarray.ndim<br>
#     the number of axes (dimensions) of the array. In the Python world, the number of dimensions is referred to as rank.
# * ndarray.shape<br>
#     the dimensions of the array. This is a tuple of integers indicating the size of the array in each dimension. For a matrix with n rows and m columns, shape will be (n,m). The length of the shape tuple is therefore the rank, or number of dimensions, ndim.
# * ndarray.size<br>
#     the total number of elements of the array. This is equal to the product of the elements of shape.
# * ndarray.dtype<br>
#     an object describing the type of the elements in the array. One can create or specify dtype’s using standard Python types. Additionally NumPy provides types of its own. numpy.int32, numpy.int16, and numpy.float64 are some examples.
# * ndarray.itemsize<br>
#     the size in bytes of each element of the array. For example, an array of elements of type float64 has itemsize 8 (=64/8), while one of type complex32 has itemsize 4 (=32/8). It is equivalent to ndarray.dtype.itemsize.
# * ndarray.data<br>
#     the buffer containing the actual elements of the array. Normally, we won’t need to use this attribute because we will access the elements in an array using indexing facilities.
#
# ###### numpy.matrix
# * [numpy.matrix](https://docs.scipy.org/doc/numpy-1.15.1/reference/generated/numpy.matrix.html)

# %%
# -*- coding: utf-8 -*-
from platform import python_version
import os, time, glob, socket
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

print("【日期時間】{}".format(time.strftime("%Y/%m/%d %H:%M:%S")))
print("【工作目錄】{}".format(os.getcwd()))
print("【主機名稱】{} ({})".format(socket.gethostname(),socket.gethostbyname(socket.gethostname())))
print("【Python】{}".format(python_version()))
# Out:
# 【日期時間】2021/04/20 14:34:32
# 【工作目錄】C:\Users\NTPU Computer Center\Desktop
# 【主機名稱】1MF08-06 (10.137.110.6)
# 【Python】3.8.5

# %% [markdown]
# <font color=#0000FF>以下是為了解決繪圖的中文無法呈現問題，因為抓不到中文字型</font>
# * [處理中文無法顯示字型問題](https://blog.csdn.net/xidianliutingting/article/details/53377659)
# * [各類蔬菜水果圖檔來源資料](https://www.google.com.tw/search?q=%E8%94%AC%E8%8F%9C%E6%B0%B4%E6%9E%9C&rlz=1C1CHZL_zh-TWTW765TW766&source=lnms&tbm=isch&sa=X&ved=0ahUKEwjczIqrirXaAhVGEbwKHaptAZgQ_AUICigB&biw=1333&bih=847)
# * [各類水果來源資料](https://www.google.com.tw/search?q=%E6%B0%B4%E6%9E%9C&rlz=1C1CHZL_zh-TWTW765TW766&source=lnms&tbm=isch&sa=X&ved=0ahUKEwinp9zFkbXaAhXFxbwKHeSfCDIQ_AUICigB&biw=1916&bih=898)

# %%
from matplotlib.font_manager import FontProperties  
font_set01 = FontProperties(fname=r"c:\windows\fonts\simsun.ttc", size=12) 
fontset02 = FontProperties(fname=r"c:\windows\fonts\kaiu.ttc", size=12)

# %% [markdown]
# ### <font color=#0000FF>numpy.ndarray 物件的基本操作</font>

# %% [markdown]
# 【參考資料】：[numpy.ndarray官方說明](https://numpy.org/doc/stable/reference/generated/numpy.ndarray.html)

# %%
arry = np.arange(15)
print(arry.shape)
arry = arry.reshape([3,5])
print(arry.shape)
print(arry.ndim)
print(arry.size)
# Out:
# (15,)
# (3, 5)
# 2
# 15

# %%
arry = np.arange(15).reshape([3,5])
print(arry.shape)
print(arry.dtype)
arry = arry.astype(np.int64)
print(arry.dtype)
# Out:
# (3, 5)
# int32
# int64

# %% [markdown]
# ### <font color=#0000FF>使用matplotlib讀入圖片檔案並顯示</font>

# %% [markdown]
# - imread() : 讀入影像檔案，成為 ndarray
# - imshow() : 將圖檔(ndarry)置放於X-Y坐標軸上
# - show() : 將圖形顯示出來

# %%
fname = r'C:\PyImages\RedBall.jpg'
img = plt.imread(fname)
print(img.shape)
print(img[:5,:5,0])   # R
print(img[:5,:5,1])   # G
print(img[:5,:5,2])   # B
print(img.dtype)
# Out:
# (2364, 1774, 3)
# [[250 255 255 249 247]
#  [251 255 255 248 247]
#  [253 255 255 250 251]
#  [252 255 254 252 254]
#  [246 250 251 252 254]]
# [[70 77 77 68 66]
#  [71 76 75 67 66]
#  [73 75 74 69 70]
#  [70 73 73 71 73]
#  [64 68 70 71 73]]
# [[45 52 50 41 39]
#  [46 51 48 40 39]
#  [48 51 47 42 43]
#  [46 49 46 44 46]
#  [40 44 43 44 46]]
# uint8

# %%
print(img[:5,:5,0])   # R
print('---------------------')
#因為Iint8溢位了，因此從0開始算
print(img[:5,:5,0] + 10)   # R
# Out:
# [[250 255 255 249 247]
#  [251 255 255 248 247]
#  [253 255 255 250 251]
#  [252 255 254 252 254]
#  [246 250 251 252 254]]
# ---------------------
# [[4 9 9 3 1]
#  [5 9 9 2 1]
#  [7 9 9 4 5]
#  [6 9 8 6 8]
#  [0 4 5 6 8]]

# %%
fname = r'C:\PyImages\RedBall.jpg'
img = plt.imread(fname)
plt.imshow(img)
plt.show()

# %% [markdown]
# <font color=#0000FF>變換顏色的位置(變色)</font>

# %%
fname = r'C:\PyImages\RedBall.jpg'
img = plt.imread(fname)
plt.imshow(img[:,:,:])
plt.show()

# %%
fname = r'C:\PyImages\RedBall.jpg'
img = plt.imread(fname)
plt.imshow(img[:,:,[2,1,0]])
plt.show()

# %%
fname = r'C:\PyImages\RedBall.jpg'
img = plt.imread(fname)
plt.imshow(img[:,:,[1,0,2]])
plt.show()

# %% [markdown]
# <font color=#0000FF>變換圖片的上、下與左、右</font>

# %%
fname = r'C:\PyImages\RedBall.jpg'
img = plt.imread(fname)
plt.imshow(img[:,:,:])
plt.show()

# %%
fname = r'C:\PyImages\RedBall.jpg'
img = plt.imread(fname)
plt.imshow(img[::-1,:,:])
plt.show()

# %%
fname = r'C:\PyImages\RedBall.jpg'
img = plt.imread(fname)
plt.imshow(img[:,::-1,:])
plt.show()

# %% [markdown]
# <font color=#0000FF>利用step進行縮圖</font>
#
# 真的縮圖不要這麼做，這樣影像會失真，可以用opencv

# %%
fname = r'C:\PyImages\RedBall.jpg'
img = plt.imread(fname)
plt.imshow(img[:,:,:])
plt.show()

# %%
fname = r'C:\PyImages\RedBall.jpg'
img = plt.imread(fname)
h = img.shape[0]
w = img.shape[1]
plt.xlim(0, w)                  # 設定 X 軸的最大、最小值
plt.ylim(h, 0)
plt.imshow(img[::2,:,:])
plt.show()

# %%
fname = r'C:\PyImages\RedBall.jpg'
img = plt.imread(fname)
h = img.shape[0]
w = img.shape[1]
plt.xlim(0, w)                  # 設定 X 軸的最大、最小值
plt.ylim(h, 0)
plt.imshow(img[::2,::2,:])
plt.show()

# %% [markdown]
# <font color=#0000FF>利用slice進行裁圖</font>

# %%
fname = r'C:\PyImages\RedBall.jpg'
img = plt.imread(fname)
plt.imshow(img[:,:,:])
plt.show()

# %%
fname = r'C:\PyImages\RedBall.jpg'
img = plt.imread(fname)
h = img.shape[0]
w = img.shape[1]
plt.xlim(0, w)                 
plt.ylim(h, 0)
plt.imshow(img[:1000,:1000,:])
plt.show()

# %% [markdown]
# <font color=#0000FF>彩色圖(RGB三維) 轉成 灰階圖(二維)</font>
# * [[OpenCV] 轉換影像為灰階 (Transform Image to Gray Level)](https://cg2010studio.com/2011/06/06/opencv-%E8%BD%89%E6%8F%9B%E5%BD%B1%E5%83%8F%E7%82%BA%E7%81%B0%E9%9A%8E-transform-image-to-gray-level/)
# * <font color=#666666>Gray</font> = *0.299* * <font color=#FF0000>Red</font> + *0.587* * <font color=#00FF00>Green</font> + *0.114* * <font color=#0000FF>Blue</font>

# %%
fname = r'C:\PyImages\RedBall.jpg'
img = plt.imread(fname)
plt.imshow(img[:,:,:])
plt.show()

# %%
print(img[:5, :5, 0])
print(img[:5, :5, 1])
print(img[:5, :5, 0] - img[:5, :5, 1])
print(img[:5, :5, 0] * 0.5)
# Out:
# [[250 255 255 249 247]
#  [251 255 255 248 247]
#  [253 255 255 250 251]
#  [252 255 254 252 254]
#  [246 250 251 252 254]]
# [[70 77 77 68 66]
#  [71 76 75 67 66]
#  [73 75 74 69 70]
#  [70 73 73 71 73]
#  [64 68 70 71 73]]
# [[180 178 178 181 181]
#  [180 179 180 181 181]
#  [180 180 181 181 181]
#  [182 182 181 181 181]
#  [182 182 181 181 181]]
# [[125.  127.5 127.5 124.5 123.5]
#  [125.5 127.5 127.5 124.  123.5]
#  [126.5 127.5 127.5 125.  125.5]
#  [126.  127.5 127.  126.  127. ]
#  [123.  125.  125.5 126.  127. ]]

# %% [markdown]
# ### [colormap](https://matplotlib.org/stable/tutorials/colors/colormaps.html)

# %%
fname = r'C:\PyImages\RedBall.jpg'
img = plt.imread(fname)

# Gray = 0.299 * Red + 0.587 * Green + 0.114 * Blue
img2 = img[:,:,0]*0.299  + img[:,:,1]*0.587  + img[:,:,2]*0.114

plt.imshow(img2, cmap='gray')   # color map
plt.show()

# %%
fname = r'C:\PyImages\神力女超人.jpg'
img = plt.imread(fname)

# Gray = 0.299 * Red + 0.587 * Green + 0.114 * Blue
img2 = img[:,:,0]*0.299  + img[:,:,1]*0.587  + img[:,:,2]*0.114

plt.imshow(img2, cmap='gray')   # color map
plt.show()

# %% [markdown]
# ### <font color=#0000FF>將所有圖檔堆疊在同一個檔案</font>
# - pickle : 低階儲存物件
# - joblib : 高階儲存物件

# %% [markdown]
# ### <font color=#0000FF>利用plt.subplot()切割畫面</font>

# %% [markdown]
# ### <font color=#0000FF>使用plt.subplot2grid()分割畫面</font>

# %% [markdown]
# ### <font color=#0000FF>利用plt.subplot()與隨機抽樣水果，寫一個拉霸遊戲</font>

# %% [markdown]
# ### <font color=#0000FF>利用plt.subplot()與隨機抽樣水果(從pickle / joblib檔案)，隨機出現3X3的水果盤</font>
